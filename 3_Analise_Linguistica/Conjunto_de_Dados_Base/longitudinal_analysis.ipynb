# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path
import string

# %%
grupos_metricas = {

    'adj_arg_ovl': 'Coesão Referencial',
    'adj_cw_ovl': 'Coesão Referencial',
    'adj_stem_ovl': 'Coesão Referencial',
    'adjacent_refs': 'Coesão Referencial',
    'anaphoric_refs': 'Coesão Referencial',
    'arg_ovl': 'Coesão Referencial',
    'coreference_pronoun_ratio': 'Coesão Referencial',
    'demonstrative_pronoun_ratio': 'Coesão Referencial',
    'stem_ovl': 'Coesão Referencial',

    'cross_entropy': 'Coesão Semântica',
    'lsa_adj_mean': 'Coesão Semântica',
    'lsa_adj_std': 'Coesão Semântica',
    'lsa_all_mean': 'Coesão Semântica',
    'lsa_all_std': 'Coesão Semântica',
    'lsa_givenness_mean': 'Coesão Semântica',
    'lsa_givenness_std': 'Coesão Semântica',
    'lsa_paragraph_mean': 'Coesão Semântica',
    'lsa_paragraph_std': 'Coesão Semântica',
    'lsa_span_mean': 'Coesão Semântica',
    'lsa_span_std': 'Coesão Semântica',

    'adjunct_per_clause': 'Complexidade Sintática',
    'adverbs_before_main_verb_ratio': 'Complexidade Sintática',
    'apposition_per_clause': 'Complexidade Sintática',
    'clauses_per_sentence': 'Complexidade Sintática',
    'coordinate_conjunctions_per_clauses': 'Complexidade Sintática',
    'dep_distance': 'Complexidade Sintática',
    'frazier': 'Complexidade Sintática',
    'infinite_subordinate_clauses': 'Complexidade Sintática',
    'non_svo_ratio': 'Complexidade Sintática',
    'passive_ratio': 'Complexidade Sintática',
    'postponed_subject_ratio': 'Complexidade Sintática',
    'ratio_coordinate_conjunctions': 'Complexidade Sintática',
    'ratio_subordinate_conjunctions': 'Complexidade Sintática',
    'relative_clauses': 'Complexidade Sintática',
    'sentences_with_five_clauses': 'Complexidade Sintática',
    'sentences_with_four_clauses': 'Complexidade Sintática',
    'sentences_with_one_clause': 'Complexidade Sintática',
    'sentences_with_seven_more_clauses': 'Complexidade Sintática',
    'sentences_with_six_clauses': 'Complexidade Sintática',
    'sentences_with_three_clauses': 'Complexidade Sintática',
    'sentences_with_two_clauses': 'Complexidade Sintática',
    'sentences_with_zero_clause': 'Complexidade Sintática',
    'std_noun_phrase': 'Complexidade Sintática',
    'subordinate_clauses': 'Complexidade Sintática',
    'temporal_adjunct_ratio': 'Complexidade Sintática',
    'words_before_main_verb': 'Complexidade Sintática',
    'yngve': 'Complexidade Sintática',

    'add_neg_conn_ratio': 'Conectivos',
    'add_pos_conn_ratio': 'Conectivos',
    'and_ratio': 'Conectivos',
    'cau_neg_conn_ratio': 'Conectivos',
    'cau_pos_conn_ratio': 'Conectivos',
    'conn_ratio': 'Conectivos',
    'if_ratio': 'Conectivos',
    'log_neg_conn_ratio': 'Conectivos',
    'log_pos_conn_ratio': 'Conectivos',
    'logic_operators': 'Conectivos',
    'negation_ratio': 'Conectivos',
    'or_ratio': 'Conectivos',

    'gerund_verbs': 'Densidade de Padrões Sintáticos',
    'max_noun_phrase': 'Densidade de Padrões Sintáticos',
    'mean_noun_phrase': 'Densidade de Padrões Sintáticos',
    'min_noun_phrase': 'Densidade de Padrões Sintáticos',

    'adjective_diversity_ratio': 'Diversidade Lexical',
    'content_density': 'Diversidade Lexical',
    'content_word_diversity': 'Diversidade Lexical',
    'content_word_max': 'Diversidade Lexical',
    'content_word_min': 'Diversidade Lexical',
    'content_word_standard_deviation': 'Diversidade Lexical',
    'function_word_diversity': 'Diversidade Lexical',
    'indefinite_pronouns_diversity': 'Diversidade Lexical',
    'noun_diversity': 'Diversidade Lexical',
    'preposition_diversity': 'Diversidade Lexical',
    'pronoun_diversity': 'Diversidade Lexical',
    'punctuation_diversity': 'Diversidade Lexical',
    'relative_pronouns_diversity_ratio': 'Diversidade Lexical',
    'ttr': 'Diversidade Lexical',
    'verb_diversity': 'Diversidade Lexical',

    'cw_freq': 'Frequência de Palavras',
    'cw_freq_bra': 'Frequência de Palavras',
    'cw_freq_brwac': 'Frequência de Palavras',
    'freq_bra': 'Frequência de Palavras',
    'freq_brwac': 'Frequência de Palavras',
    'min_cw_freq': 'Frequência de Palavras',
    'min_cw_freq_bra': 'Frequência de Palavras',
    'min_cw_freq_brwac': 'Frequência de Palavras',
    'min_freq_bra': 'Frequência de Palavras',
    'min_freq_brwac': 'Frequência de Palavras',

    'brunet': 'Índices de Leiturabilidade',
    'dalechall_adapted': 'Índices de Leiturabilidade',
    'flesch': 'Índices de Leiturabilidade',
    'gunning_fox': 'Índices de Leiturabilidade',
    'honore': 'Índices de Leiturabilidade',

    ' adjective_ratio': 'Informações Morfossintáticas de Palavras',
    'adjectives_max': 'Informações Morfossintáticas de Palavras',
    'adjectives_min': 'Informações Morfossintáticas de Palavras',
    'adjectives_standard_deviation': 'Informações Morfossintáticas de Palavras',
    'adverbs': 'Informações Morfossintáticas de Palavras',
    'adverbs_diversity_ratio': 'Informações Morfossintáticas de Palavras',
    'adverbs_max': 'Informações Morfossintáticas de Palavras',
    'adverbs_min': 'Informações Morfossintáticas de Palavras',
    'adverbs_standard_deviation': 'Informações Morfossintáticas de Palavras',
    'content_words': 'Informações Morfossintáticas de Palavras',
    'first_person_possessive_pronouns': 'Informações Morfossintáticas de Palavras',
    'first_person_pronouns': 'Informações Morfossintáticas de Palavras',
    'function_words': 'Informações Morfossintáticas de Palavras',
    'indefinite_pronoun_ratio': 'Informações Morfossintáticas de Palavras',
    'indicative_condition_ratio': 'Informações Morfossintáticas de Palavras',
    'indicative_future_ratio': 'Informações Morfossintáticas de Palavras',
    'infinitive_verbs': 'Informações Morfossintáticas de Palavras',
    'inflected_verbs': 'Informações Morfossintáticas de Palavras',
    'negative_words': 'Informações Morfossintáticas de Palavras',
    'non-inflected_verbs': 'Informações Morfossintáticas de Palavras',
    'noun_ratio': 'Informações Morfossintáticas de Palavras',
    'nouns_max': 'Informações Morfossintáticas de Palavras',
    'nouns_min': 'Informações Morfossintáticas de Palavras',
    'nouns_standard_deviation': 'Informações Morfossintáticas de Palavras',
    'oblique_pronouns_ratio': 'Informações Morfossintáticas de Palavras',
    'personal_pronouns': 'Informações Morfossintáticas de Palavras',
    'positive_words': 'Informações Morfossintáticas de Palavras',
    'prepositions_per_clause': 'Informações Morfossintáticas de Palavras',
    'prepositions_per_sentence': 'Informações Morfossintáticas de Palavras',
    'pronoun_ratio': 'Informações Morfossintáticas de Palavras',
    'pronouns_max': 'Informações Morfossintáticas de Palavras',
    'pronouns_min': 'Informações Morfossintáticas de Palavras',
    'pronouns_standard_deviation': 'Informações Morfossintáticas de Palavras',
    'punctuation_ratio': 'Informações Morfossintáticas de Palavras',
    'ratio_function_to_content_words': 'Informações Morfossintáticas de Palavras',
    'relative_pronouns_ratio': 'Informações Morfossintáticas de Palavras',
    'second_person_possessive_pronouns': 'Informações Morfossintáticas de Palavras',
    'second_person_pronouns': 'Informações Morfossintáticas de Palavras',
    'third_person_possessive_pronouns': 'Informações Morfossintáticas de Palavras',
    'third_person_pronouns': 'Informações Morfossintáticas de Palavras',
    'verbs': 'Informações Morfossintáticas de Palavras',
    'verbs_max': 'Informações Morfossintáticas de Palavras',
    'verbs_min': 'Informações Morfossintáticas de Palavras',
    'verbs_standard_deviation': 'Informações Morfossintáticas de Palavras',

    'abstract_nouns_ratio': 'Informações Semânticas de Palavras',
    'adjectives_ambiguity': 'Informações Semânticas de Palavras',
    'adverbs_ambiguity': 'Informações Semânticas de Palavras',
    'content_words_ambiguity': 'Informações Semânticas de Palavras',
    'hypernyms_verbs': 'Informações Semânticas de Palavras',
    'named_entity_ratio_sentence': 'Informações Semânticas de Palavras',
    'named_entity_ratio_text': 'Informações Semânticas de Palavras',
    'nouns_ambiguity': 'Informações Semânticas de Palavras',
    'verbs_ambiguity': 'Informações Semânticas de Palavras',

    'aux_plus_PCP_per_sentence': 'Léxico Temporal',
    'indicative_imperfect_ratio': 'Léxico Temporal',
    'indicative_pluperfect_ratio': 'Léxico Temporal',
    'indicative_present_ratio': 'Léxico Temporal',
    'indicative_preterite_perfect_ratio': 'Léxico Temporal',
    'participle_verbs': 'Léxico Temporal',
    'subjunctive_future_ratio': 'Léxico Temporal',
    'subjunctive_imperfect_ratio': 'Léxico Temporal',
    'subjunctive_present_ratio': 'Léxico Temporal',
    'tmp_neg_conn_ratio': 'Léxico Temporal',
    'tmp_pos_conn_ratio': 'Léxico Temporal',
    'verbal_time_moods_diversity': 'Léxico Temporal',

    'paragraphs': 'Medidas Descritivas',
    'sentence_length_max': 'Medidas Descritivas',
    'sentence_length_min': 'Medidas Descritivas',
    'sentence_length_standard_deviation': 'Medidas Descritivas',
    'sentences': 'Medidas Descritivas',
    'sentences_per_paragraph': 'Medidas Descritivas',
    'subtitles': 'Medidas Descritivas',
    'syllables_per_content_word': 'Medidas Descritivas',
    'words': 'Medidas Descritivas',
    'words_per_sentence': 'Medidas Descritivas',

    'concretude_1_25_ratio': 'Medidas Psicolinguísticas',
    'concretude_25_4_ratio': 'Medidas Psicolinguísticas',
    'concretude_4_55_ratio': 'Medidas Psicolinguísticas',
    'concretude_55_7_ratio': 'Medidas Psicolinguísticas',
    'concretude_mean': 'Medidas Psicolinguísticas',
    'concretude_std': 'Medidas Psicolinguísticas',
    'familiaridade_1_25_ratio': 'Medidas Psicolinguísticas',
    'familiaridade_25_4_ratio': 'Medidas Psicolinguísticas',
    'familiaridade_4_55_ratio': 'Medidas Psicolinguísticas',
    'familiaridade_55_7_ratio': 'Medidas Psicolinguísticas',
    'familiaridade_mean': 'Medidas Psicolinguísticas',
    'familiaridade_std': 'Medidas Psicolinguísticas',
    'idade_aquisicao_1_25_ratio': 'Medidas Psicolinguísticas',
    'idade_aquisicao_25_4_ratio': 'Medidas Psicolinguísticas',
    'idade_aquisicao_4_55_ratio': 'Medidas Psicolinguísticas',
    'idade_aquisicao_55_7_ratio': 'Medidas Psicolinguísticas',
    'idade_aquisicao_mean': 'Medidas Psicolinguísticas',
    'idade_aquisicao_std': 'Medidas Psicolinguísticas',
    'imageabilidade_1_25_ratio': 'Medidas Psicolinguísticas',
    'imageabilidade_25_4_ratio': 'Medidas Psicolinguísticas',
    'imageabilidade_4_55_ratio': 'Medidas Psicolinguísticas',
    'imageabilidade_55_7_ratio': 'Medidas Psicolinguísticas',
    'imageabilidade_mean': 'Medidas Psicolinguísticas',
    'imageabilidade_std': 'Medidas Psicolinguísticas',
    
    'dialog_pronoun_ratio': 'Simplicidade Textual',
    'easy_conjunctions_ratio': 'Simplicidade Textual',
    'hard_conjunctions_ratio': 'Simplicidade Textual',
    'long_sentence_ratio': 'Simplicidade Textual',
    'medium_long_sentence_ratio': 'Simplicidade Textual',
    'medium_short_sentence_ratio': 'Simplicidade Textual',
    'short_sentence_ratio': 'Simplicidade Textual',
    'simple_word_ratio': 'Simplicidade Textual'
}

# %%
print(Path.cwd())

# %%
df_metrics_portuguese = pd.read_csv(
    Path("metrics_portuguese.csv"),
    encoding="utf-8"
)

df_main = pd.read_csv(
    Path("..") / ".." / "2_Construcao_do_Corpus_de_Resumos_Cientificos"
    / "metadados_completos_sol_sbc_com_idioma_area_introducao_conclusao.csv",
    encoding="utf-8"
)

# %%
df_metrics_portuguese.info()

# %%
df_main.info()

# %%
import langdetect

def abstract_language(abstract):
    
    if pd.isna(abstract):
        return None

    try:
        lang = langdetect.detect(abstract)
        return lang
    except Exception as e:
        print(f"Erro ao detectar idioma do abstract: {e}")
        return None


df_main["Abstract_Language"] = df_main["Abstract"].apply(abstract_language)

# %%
df_main_portuguese = df_main[df_main['Abstract_Language'] == 'pt']

# %%
df_main_portuguese.info()

# %%
df = pd.merge(df_metrics_portuguese, df_main_portuguese, left_on='id_texto', right_on='index', how='inner')

# %%
df.head()

# %% [markdown]
# # Análise de Frequência Esperada vs Frequência Observada das Palavras (Não Finalizado)

# %%
import pandas as pd
import string
import nltk

df_main_portuguese["Abstract"] = df_main_portuguese["Abstract"].fillna("").astype(str)
espacos = ' ' * len(string.punctuation)
tabela_limpeza = str.maketrans(string.punctuation, espacos)

df_main_portuguese["Abstract_clean"] = df_main_portuguese["Abstract"].str.translate(tabela_limpeza).str.lower()

df_palavras = df_main_portuguese.assign(Palavra=df_main_portuguese["Abstract_clean"].str.split()).explode("Palavra")

df_palavras = df_palavras[
    (df_palavras["Palavra"] != "") &
    (~df_palavras["Palavra"].str.isnumeric())
]

matriz_ocorrencias = pd.crosstab(df_palavras["Palavra"], df_palavras["Year"])

unicas_por_ano = (matriz_ocorrencias > 0).sum(axis=0)

matriz_frequencia = matriz_ocorrencias.div(unicas_por_ano, axis=1)

# %%
import pandas as pd
import string

df_main_portuguese["Abstract"] = df_main_portuguese["Abstract"].fillna("").astype(str)
espacos = ' ' * len(string.punctuation)
tabela_limpeza = str.maketrans(string.punctuation, espacos)

df_main_portuguese["Abstract_clean"] = df_main_portuguese["Abstract"].str.translate(tabela_limpeza).str.lower()

df_palavras = df_main_portuguese.assign(Palavra=df_main_portuguese["Abstract_clean"].str.split()).explode("Palavra")

df_palavras = df_palavras[
    (df_palavras["Palavra"] != "") &
    (~df_palavras["Palavra"].str.isnumeric())
]

matriz_ocorrencias = pd.crosstab(df_palavras["Palavra"], df_palavras["Year"])

total_palavras_por_ano = matriz_ocorrencias.sum(axis=0)

matriz_frequencia = matriz_ocorrencias.div(total_palavras_por_ano, axis=1)

# %%
matriz_frequencia.head(3000)

# %%
top_por_ano_df = pd.DataFrame({
    ano: matriz_frequencia[ano].nlargest(50).index 
    for ano in matriz_frequencia.columns
})

top_por_ano_df.head(50)

# %%
import pandas as pd
import numpy as np

anos_historicos = [col for col in matriz_frequencia.columns if col <= 2022]
anos_posteriores = [col for col in matriz_frequencia.columns if col > 2022]

df_esperada = pd.DataFrame(index=matriz_frequencia.index)
df_diferenca = pd.DataFrame(index=matriz_frequencia.index)

X_hist = np.array(anos_historicos)

for palavra, linha in matriz_frequencia.iterrows():
    y_hist = linha[anos_historicos].values
    
    if np.all(y_hist == 0):
        a, b = 0, 0
    else:
        a, b = np.polyfit(X_hist, y_hist, 1)
    
    for ano in anos_posteriores:
        freq_esperada = max(0, a * ano + b)
        freq_observada = linha[ano]
        
        df_esperada.loc[palavra, ano] = freq_esperada
        df_diferenca.loc[palavra, ano] = freq_observada - freq_esperada

print("=== TOP CRESCIMENTO INCOMUM PÓS-2022 ===")
for ano in anos_posteriores:
    print(f"\n--- ANO: {ano} ---")
    top_crescimento = df_diferenca[ano].sort_values(ascending=False).head(50)
    
    resumo_ano = pd.DataFrame({
        'Freq. Observada': matriz_frequencia.loc[top_crescimento.index, ano],
        'Freq. Esperada': df_esperada.loc[top_crescimento.index, ano],
        'Diferença (Obs - Esp)': top_crescimento
    })
    print(resumo_ano)

# %% [markdown]
# # Análise do Z-Score das Métricas Linguísticas

# %% [markdown]
# Cálculo das médias anuais de cada Medida Linguística

# %%
colunas_metadados = {
    "Title", "Category", "URL_Title", "Authors", "Event", "Date", "Box",
    "Abstract", "Keywords", "Publisher", "URL_Paper", "index", "Year",
    "Paper_Language", "has_intro", "has_conclusion", "flag_intro_conc",
    "Introduction", "Conclusion", "Area", "Abstract_Language",
    "Abstract_clean", "id_texto" 
}

colunas_metricas = [
    c for c in df.columns
    if c not in colunas_metadados and pd.api.types.is_numeric_dtype(df[c])
]

print(f"\nQuantidade de métricas: {len(colunas_metricas)}")

medias_anuais = df.groupby("Year")[colunas_metricas].mean().sort_index()

# %%
print("\nMédias anuais das métricas NILC-Metrix:")
medias_anuais.head(40)

# %% [markdown]
# Neste momento são calculados as variações ano a ano
#
# variação = ((valor_atual - valor_anterior) / valor_anterior)*100

# %%
variacoes = medias_anuais.pct_change() * 100
variacoes = variacoes.dropna(how="all")

# %%
variacoes.head()

# %% [markdown]
# Cálculo da Média entre as variações anteriores ao ano corte, no caso 2023

# %%
ANO_CORTE = 2023

variacoes_historicas = variacoes[
    variacoes.index < ANO_CORTE
].copy()


variacoes_historicas = variacoes_historicas.replace(
    [np.inf, -np.inf],
    np.nan
)

estatisticas_historicas = pd.DataFrame({
    "métrica": variacoes_historicas.columns,
    "media_hist": variacoes_historicas.mean(),
    "desvio_hist": variacoes_historicas.std(),
    "n_hist": variacoes_historicas.count()
})

estatisticas_historicas['Grupo'] = estatisticas_historicas['métrica'].map(grupos_metricas)

# %%
estatisticas_historicas.head(50)

# %% [markdown]
# Variações específicas de interesse

# %%
anos_interesse = [2023, 2024, 2025] 
variacoes_interesse = variacoes.loc[variacoes.index.isin(anos_interesse)]

print("\nVariações nos anos de interesse (%):")
print(variacoes_interesse.T.head(50))

# %% [markdown]
# Identificação de métricas com variações excepcionais (z-score)
#
# Calcula o Z-score de cada variação anual em relação à média e ao desvio-padrão históricos da respectiva métrica. Em seguida, classifica como excepcional as variações cujo valor absoluto do Z-score ultrapassa o limiar definido e apresenta os casos mais extremos.

# %%
def calcular_zscores(variacoes_interesse, estatisticas_historicas):

    resultados = []
    for ano in variacoes_interesse.index:
        for metrica in variacoes_interesse.columns:
            var_obs = variacoes_interesse.loc[ano, metrica]
            media_h = estatisticas_historicas.loc[metrica, "media_hist"]
            desvio_h = estatisticas_historicas.loc[metrica, "desvio_hist"]

            if pd.isna(var_obs) or pd.isna(media_h) or pd.isna(desvio_h) or desvio_h == 0:
                z = np.nan
            else:
                z = (var_obs - media_h) / desvio_h

            resultados.append({
                "Metrica": metrica,
                "Transicao": f"{ano-1}->{ano}",
                "Variacao_%": var_obs,
                "Media_Historica_%": media_h,
                "Desvio_Historico_%": desvio_h,
                "Z_score": z
            })
    return pd.DataFrame(resultados)


tabela_zscores = calcular_zscores(variacoes_interesse, estatisticas_historicas)

# 
LIMIAR_Z = 2.0
tabela_zscores["Excepcional"] = tabela_zscores["Z_score"].abs() > LIMIAR_Z

metricas_excepcionais = (
    tabela_zscores[tabela_zscores["Excepcional"]]
    .sort_values("Z_score", key=lambda x: x.abs(), ascending=False)
)

print(f"\nMétricas com variação excepcional (|z| > {LIMIAR_Z}):")
print(metricas_excepcionais[["Metrica", "Transicao", "Variacao_%", "Z_score"]].head(30))

# %%
metricas_excepcionais.head()

# %%
for transicao in tabela_zscores["Transicao"].unique():
    sub = tabela_zscores[tabela_zscores["Transicao"] == transicao]
    top_alteradas = sub.reindex(sub["Z_score"].abs().sort_values(ascending=False).index).head(20)
    print(f"\n=== Top 20 métricas mais alteradas em {transicao} ===")
    print(top_alteradas[["Metrica", "Variacao_%", "Z_score"]].to_string(index=False))

top_metricas_geral = (
    tabela_zscores.groupby("Metrica")["Z_score"]
    .apply(lambda x: x.abs().max())
    .sort_values(ascending=False)
    .head(25)
    .index
)

pivot_zscore = tabela_zscores[tabela_zscores["Metrica"].isin(top_metricas_geral)].pivot(
    index="Metrica", columns="Transicao", values="Z_score"
)

plt.figure(figsize=(8, 10))
sns.heatmap(pivot_zscore, annot=True, fmt=".1f", cmap="coolwarm", center=0)
plt.title("Z-score das métricas mais alteradas por transição de ano")
plt.tight_layout()
plt.show()

transicao_alvo = "2022->2023"
if transicao_alvo in tabela_zscores["Transicao"].values:
    sub = tabela_zscores[tabela_zscores["Transicao"] == transicao_alvo]
    top_sub = sub.reindex(sub["Z_score"].abs().sort_values(ascending=False).index).head(15)

    plt.figure(figsize=(10, 6))
    sns.barplot(data=top_sub, x="Variacao_%", y="Metrica", palette="vlag")
    plt.title(f"Top 15 métricas com maior alteração ({transicao_alvo})")
    plt.xlabel("Variação (%)")
    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt

config_grupos = {
    "Informações Morfossintáticas de Palavras": {
        "metricas": [
            "function_words",
            "content_words",
            "ratio_function_to_content_words",
            "prepositions_per_sentence",
            "pronoun_ratio",
        ],
        "layout": (2, 3),
        "figsize": (15, 8),
    },
    "Psicolinguística": {
        "metricas": [
            "idade_aquisicao_25_4_ratio",
            "idade_aquisicao_mean",
        ],
        "layout": (1, 2),
        "figsize": (12, 4),
    },
    "Complexidade Sintática": {
        "metricas": [
            "sentences_with_zero_clause",
            "clauses_per_sentence",
        ],
        "layout": (1, 2),
        "figsize": (12, 4),
    },
    "Diversidade Lexical": {
        "metricas": ["content_density"],
        "layout": (1, 1),
        "figsize": (7, 4),
    },
}


def plot_grupo_customizado(nome_grupo, config, df, ano_corte):
    metricas = config["metricas"]
    nrows, ncols = config["layout"]

    fig, axes = plt.subplots(
        nrows=nrows, ncols=ncols, figsize=config["figsize"]
    )

    if nrows * ncols == 1:
        axes_list = [axes]
    else:
        axes_list = axes.flatten()

    # Plotagem de cada métrica no seu subplot correspondente
    for i, metrica in enumerate(metricas):
        ax = axes_list[i]

        if metrica in df.columns:
            ax.plot(
                df.index,
                df[metrica],
                marker="o",
                linewidth=2,
                color="tab:blue",
                label=metrica,
            )
            ax.axvline(
                x=ano_corte - 0.5,
                color="red",
                linestyle="--",
                alpha=0.7,
                label="Início IA Generativa",
            )

            ax.set_title(metrica, fontsize=10, fontweight="bold")
            ax.set_xlabel("Ano")
            ax.set_ylabel("Valor médio")
            ax.grid(True, linestyle=":", alpha=0.6)
            ax.legend(loc="upper right", fontsize=8)
        else:
            ax.text(
                0.5,
                0.5,
                f"Coluna '{metrica}'\nnão encontrada",
                ha="center",
                va="center",
                transform=ax.transAxes,
            )

    # Oculta subplots extras (ex: a 6ª posição vazia no grid 2x3)
    for j in range(len(metricas), len(axes_list)):
        fig.delaxes(axes_list[j])

    fig.suptitle(
        f"Grupo: {nome_grupo}", fontsize=13, fontweight="bold", y=1.02
    )
    plt.tight_layout()
    plt.show()

ANO_CORTE = 2022  # Defina aqui o ano de corte do seu estudo

for grupo, config in config_grupos.items():
    plot_grupo_customizado(grupo, config, medias_anuais, ANO_CORTE)

# %% [markdown]
# # T-test de Welch

# %%
import statistics
from scipy import stats

# %%
df.head()

# %%
list_metrics = df.columns.tolist()[1:201]

# %%
df_metrics = pd.DataFrame(columns=['Métrica', 'n', 'Ano', 'Média', 'Mediana', 'Desvio Padrão'])

for metric in list_metrics:
    for year in range(min(df['Year']), max(df['Year']) + 1):
        subset = df[df['Year'] == year]
        mean_value = subset[metric].mean()
        n = len(subset[metric])
        median_value = statistics.median(subset[metric].dropna())
        std_value = subset[metric].std()
        df_metrics = pd.concat([
            df_metrics,
            pd.DataFrame({
                'Métrica': [metric],
                'n': [n],
                'Ano': [year],
                'Média': [mean_value],
                'Mediana': [median_value],
                'Desvio Padrão': [std_value]  
            })
        ], ignore_index=True)

df_metrics.head(6)

# %%
pip install scipy

# %%
df_copy = df_metrics.copy()

baseline_years = [ano for ano in range(df_copy['Ano'].min(), 2023)]

baseline_results = []


for metric in df_copy['Métrica'].unique():
    df_metric = df_copy[df_copy['Métrica'] == metric]
    
    
    df_base = df_metric[df_metric['Ano'].isin(baseline_years)]
    
    
    n1 = df_base['n'].sum()
    
    
    s1_squared = np.sum((df_base['n'] - 1) * df_base['Desvio Padrão']**2) / (n1 - len(df_base))
    
    
    x1 = np.average(df_base['Média'], weights=df_base['n'])
    
    baseline_results.append({
        'Métrica': metric,
        'n_baseline': n1,
        'Média_baseline': x1,
        'Variância_baseline': s1_squared,
        'DP_baseline': np.sqrt(s1_squared)
    })

df_baseline = pd.DataFrame(baseline_results)

df_baseline.head()

# %%
df_copy = df_metrics.copy()

# Definindo os anos pós-baseline
post_years = [2023, 2024, 2025]

# Inicializa lista para resultados do t-test
results = []

for metric in df_copy['Métrica'].unique():
    # Busca baseline calculado
    base = df_baseline[df_baseline['Métrica'] == metric].iloc[0]
    x1 = base['Média_baseline']
    s1_squared = base['Variância_baseline']
    n1 = base['n_baseline']
    
    # Dados da métrica para anos pós-baseline
    df_metric_post = df_copy[(df_copy['Métrica'] == metric) & (df_copy['Ano'].isin(post_years))]
    
    for idx, row in df_metric_post.iterrows():
        x2 = row['Média']
        s2_squared = row['Desvio Padrão']**2
        n2 = row['n']
        
        # Evita zero na variância
        s1_squared = max(s1_squared, 1e-10)
        s2_squared = max(s2_squared, 1e-10)
        n1_safe = max(n1, 2)
        n2_safe = max(n2, 2)
        
        # Erro padrão
        SE = np.sqrt(s1_squared / n1_safe + s2_squared / n2_safe)
        
        # t-statistic
        t_stat = (x1 - x2) / SE
        
        # Graus de liberdade aproximado de Welch
        numerator = (s1_squared/n1_safe + s2_squared/n2_safe)**2
        denominator = (s1_squared/n1_safe)**2 / (n1_safe - 1) + (s2_squared/n2_safe)**2 / (n2_safe - 1)
        df_welch = numerator / denominator if denominator != 0 else np.nan
        
        # p-value (t bilateral)
        if not np.isnan(df_welch):
            p_val = 2 * (1 - stats.t.cdf(abs(t_stat), df=df_welch))
        else:
            # aproximação normal se df inválido
            p_val = 2 * (1 - stats.norm.cdf(abs(t_stat)))
        
        # Diferença e interpretação
        diff = x2 - x1
        signif = "Altamente significativo" if p_val < 0.001 else ("Significativo" if p_val < 0.05 else "Não significativo")
        direction = "Aumento" if diff > 0 else ("Diminuição" if diff < 0 else "-")
        
        results.append({
            'Métrica': metric,
            'Ano': row['Ano'],
            'X1': x1,
            'n1': n1,
            's1_squared': s1_squared,
            'X2': x2,
            'n2': n2,
            's2_squared': s2_squared,
            'Diferença média': diff,
            't': t_stat,
            'p-value': p_val,
            'Significância': signif,
            'Direção': direction
        })

df_results = pd.DataFrame(results)
df_results.head(10)

# %%
df_results['Grupo'] = df_results['Métrica'].map(grupos_metricas)

# %%
df_results.head()

# %%
df_results.to_csv(
    'analise_t_test_metricas_linguisticas.csv',
    index=False,
    sep=';',      
    decimal=','   
)

# %%
df_results.groupby('Ano')['Significância'].value_counts()

# %%
total = (
    df_results
    .groupby(['Ano', 'Significância'])
    .size()
    .reset_index(name='Total')
)

# Pivot
pivot_df = total.pivot(index='Ano', columns='Significância', values='Total')

# Plot stacked bar
pivot_df.plot(kind="bar", stacked=True)

plt.title("Proporção de Métricas por Tipo de Significância")
plt.xlabel("Ano")
plt.ylabel("Total de Métricas")
plt.legend(title="Tipo de Significância")
plt.xticks(rotation=0)
plt.tight_layout()

plt.show()

# %%
df_results.groupby('Ano')['Direção'].value_counts()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_sig = df_results[df_results["Significância"] == "Altamente significativo"]

grouped = (
    df_sig.groupby(["Ano", "Direção"])
    .size()
    .reset_index(name="Quantidade")
)

pivot = grouped.pivot(index="Ano", columns="Direção", values="Quantidade").fillna(0)

pivot = pivot.reindex([2023, 2024, 2025])

pivot.plot(kind="line", marker="o")

plt.title("Direção das Mudanças por Ano")
plt.xlabel("Ano")
plt.ylabel("Quantidade de métricas altamente significativas")
plt.xticks([2023, 2024, 2025])
plt.legend(title="Direção")
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
df_results.info()

# %% [markdown]
# ### Análise por Grupo Linguístico

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_pos = df_results[df_results['Ano'].isin([2024, 2025])].copy()

df_altamente = df_pos[
    df_pos['Significância'] == 'Altamente significativo'
].copy()

metricas_2024 = set(
    df_altamente.loc[
        df_altamente['Ano'] == 2024,
        'Métrica'
    ]
)

metricas_2025 = set(
    df_altamente.loc[
        df_altamente['Ano'] == 2025,
        'Métrica'
    ]
)


# Métricas altamente significativas nos dois anos
metricas_comuns = metricas_2024.intersection(metricas_2025)

print(f'Métricas selecionadas: {len(metricas_comuns)}')

df_historico = df_results[
    df_results['Métrica'].isin(metricas_comuns)
].copy()

for grupo in sorted(df_historico['Grupo'].unique()):

    df_grupo = df_historico[
        df_historico['Grupo'] == grupo
    ].copy()

    plt.figure(figsize=(12, 7))

    for metrica, dados_metrica in df_grupo.groupby('Métrica'):

        dados_metrica = dados_metrica.sort_values('Ano')

        plt.plot(
            dados_metrica['Ano'],
            dados_metrica['X2'],
            marker='o',
            linewidth=2,
            label=metrica
        )

    plt.title(
        'Grupo Linguístico - ' f'{grupo}\n'
    )

    plt.xlabel('Ano')
    plt.ylabel('X2')

    anos = sorted(df_grupo['Ano'].unique())
    plt.xticks(anos, rotation=45)

    plt.legend(
        title='Métrica',
        bbox_to_anchor=(1.05, 1),
        loc='upper left'
    )

    plt.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Presença por Artigo

# %%
metrics_key = (
    df_results
    .loc[
        (df_results['Ano'] == 2024) &
        (df_results['Significância'] == 'Altamente significativo'),
        'Métrica'
    ]
    .to_frame()
    .merge(
        df_results.loc[
            (df_results['Ano'] == 2025) &
            (df_results['Significância'] == 'Altamente significativo'),
            ['Métrica']
        ],
        on='Métrica'
    )['Métrica']
    .unique()
)

metrics_key = list(metrics_key)

print(len(metrics_key))
print(metrics_key)

# %%
# Converter variância em desvio-padrão
df_results['DP'] = np.sqrt(df_results['s2_squared'])
df_results.head()

# %%
stats_lookup = {
    (row['Ano'], row['Métrica']): (row['X2'], row['DP'])
    for _, row in df_results.iterrows()
}
stats_lookup

# %%
def compute_z_score(article_row, metric):
    key = (article_row['Year'], metric)

    if key not in stats_lookup:
        return np.nan

    mu, sd = stats_lookup[key]

    if sd == 0 or pd.isna(article_row[metric]):
        return np.nan

    return (article_row[metric] - mu) / sd

z_df = pd.DataFrame(index=df.index)

for metric in metrics_key:
    z_df[metric] = df.apply(compute_z_score, axis=1,metric=metric)

df['at_least_one_metric_z_lt_1'] = (z_df.abs() < 1).any(axis=1)

summary = (
    df
    .groupby('Year')['at_least_one_metric_z_lt_1']
    .agg(
        total_articles='count',
        articles_with_z_lt_1='sum'
    )
)

summary['percentage'] = (
    summary['articles_with_z_lt_1'] /
    summary['total_articles'] * 100
)


print(summary)

# %%
import pandas as pd
import numpy as np

def count_metrics_within_dp(article_row, year, k=1):
    count = 0

    for metric in metrics_key:
        key = (year, metric)

        if key not in stats_lookup:
            continue

        mu, sd = stats_lookup[key]

        if sd == 0 or pd.isna(sd):
            continue

        value = article_row.get(metric)

        if pd.isna(value):
            continue

        if (mu - k * sd) <= value <= (mu + k * sd):
            count += 1

    return count

df['metrics_within_1dp'] = df.apply(
    lambda row: count_metrics_within_dp(row, row['Year']),
    axis=1
)


metric_thresholds = [20, 40, 60, 80, 100]

for MIN_METRICS in metric_thresholds:

    # Critério por artigo
    df['meets_criterion'] = (
        df['metrics_within_1dp'] >= MIN_METRICS
    )

    # Agregação por ano
    summary = (
        df
        .groupby('Year')
        .agg(
            total_articles=('meets_criterion', 'size'),
            articles_with_criterion=('meets_criterion', 'sum')
        )
        .reset_index()
    )

    summary['percentage'] = (
        summary['articles_with_criterion'] /
        summary['total_articles'] * 100
    )

    # Metadado explícito do critério
    summary['min_metrics'] = MIN_METRICS

    # 3. Exportação do CSV
    output_name = (
        f'resultado_dp_min_{MIN_METRICS}_metricas.csv'
    )

    summary.to_csv(
        output_name,
        index=False,
        encoding='utf-8'
    )

    print(f'Arquivo gerado: {output_name}')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Leitura e consolidação
files = [
    'resultado_dp_min_20_metricas.csv',
    'resultado_dp_min_40_metricas.csv',
    'resultado_dp_min_60_metricas.csv',
    'resultado_dp_min_80_metricas.csv',
    'resultado_dp_min_100_metricas.csv'
]

df_all = pd.concat(
    [pd.read_csv(f) for f in files],
    ignore_index=True
)

# Garantir ordenação correta no eixo X
df_all = df_all.sort_values('min_metrics')

# 2. Gráfico único (2023–2025)
plt.figure()

for year in [2023, 2024, 2025]:
    df_year = df_all[df_all['Year'] == year]

    plt.plot(
        df_year['min_metrics'],
        df_year['percentage'],
        marker='o',
        label=str(year)
    )

plt.xlabel('Número mínimo de métricas dentro de ±1 DP')
plt.ylabel('Percentual de artigos (%)')
plt.title('Percentual de artigos com métricas dentro de ±1 DP')
plt.ylim(0, 110)
plt.legend(title='Ano')
plt.grid(True)

plt.show()
